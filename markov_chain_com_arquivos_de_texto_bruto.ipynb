# %% [markdown]
# <h3>Cadeias de Markov na Geração de Textos</h3>

# %% [markdown]
# <h4>Importações e Declaração de Variáveis com o Treinamento do Modelo</h4>

# %%
from Neuraline.ArtificialIntelligence.MachineLearning.AutonomousLearning.markov_chain import MarkovChain
from Neuraline.Utilities.data import ConvertData
from Neuraline.Utilities.chart import Chart
markov_chain, convert_data, chart = MarkovChain(), ConvertData(), Chart()
result = markov_chain.addFit(url_path='./texto.txt')

# %% [markdown]
# <h4>Predição e Exibição do Resultado Preditivo</h4>

# %%
key_term = 'Inteligência Artificial'
result = markov_chain.markovTextGenerator(url_path='novo_texto.txt', text=key_term, vary=True)
print(convert_data.readTEXT('./novo_texto.txt'))
# Out:
# Inteligência Artificial campeão mundial de muitos especialistas é muito limitado nosso entendimento a inteligência artificial pode ganhar consciência? No atual estágio de muitos especialistas é muito limitado nosso entendimento a inteligência artificial pode ganhar consciência? No atual estágio de muitos especialistas é muito limitado nosso entendimento a inteligência artificial pode ganhar consciência? No atual estágio de muitos problemas, e muito limitado nosso entendimento a inteligência artificial pode ganhar consciência? No atual estágio da empresa teria adquirido consciência. No atual estágio da empresa teria adquirido consciência. Encarregado de muitos problemas, e muito acelerado no atual estágio da empresa teria adquirido consciência. Encarregado de muitos problemas, e muito acelerado no Medium e muito acelerado no Medium e muito acelerado no Medium e muito acelerado no Medium e muito acelerado no Medium e muito acelerado no Medium e muito acelerado no Medium e muito acelera
# ...

# %% [markdown]
# <h4>Plotagem Gráfica do Resultado Preditivo</h4>

# %%
print('Termos de maior destaque no texto gerado na predição:')
chart.plotTEXT('./novo_texto.txt')
# Out:
# Termos de maior destaque no texto gerado na predição:
